# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(color_codes = True)

# %%
df = pd.read_csv("C:/Users/maity/OneDrive/Desktop/Bakapart2/Cases_registered_under_PCA_act_and_related_sections_IPC_2013.csv")

# %%
df.head(5)
# Out:
#             STATE/UT  YEAR  Pending Investigation From Previous Year  \
# 0     Andhra Pradesh  2013                                       348
# 1  Arunachal Pradesh  2013                                        26
# 2              Assam  2013                                        64
# 3              Bihar  2013                                       171
# 4       Chhattisgarh  2013                                       114
#
#    Cases Regd. During Year  Total Cases For Investigation  Cases Investigated  \
# 0                      362                            710                 201
# 1                        9                             35                  35
# 2                        7                             71                  71
# 3                       86                            257                 257
# 4                       37                            151                 151
#
#    Cases Not Investigated Or Investigation Dropped  \
# 0                                                1
# 1                                                0
# 2                                                0
# 3                                                0
# 4                                                0
#
#    Cases Declared False Etc. During Year  Cases Charge Sheeted  \
# 0                                      0                   140
# 1                                      0                     1
# 2                                      0                     3
# 3                                      0                    91
# 4                                      0                    31
#
#    Cases Pending For Prosecution  ...  \
# 0                             34  ...
# 1                             41  ...
# 2                              0  ...
# 3                             66  ...
# 4                             88  ...
#
#    Value Of Property Recovered / Seized (In Rupees)  \
# 0                                          34094922
# 1                                                 0
# 2                                                 0
# 3                                           1977467
# 4                                           6728329
#
#    Cases Pending Trial From The Previous Year  \
# 0                                        1054
# 1                                          14
# 2                                          43
# 3                                        1106
# 4                                         202
#
#    Cases Sent Up For Trial During The Year  Total Cases For Trial  \
# 0                                      140                   1194
# 1                                        1                     15
# 2                                        3                     46
# 3                                       91                   1197
# 4                                       31                    233
#
#    Cases Withdrawn/Discharged Or Other Wise Disposed Of  \
# 0                                                  8
# 1                                                  0
# 2                                                  0
# 3                                                  6
# 4                                                  0
#
#    Trials Completed During The Year  Cases Convicted  \
# 0                               101               43
# 1                                 0                0
# 2                                 6                5
# 3                                25                9
# 4                                13                5
#
#    Cases Acquitted Or Discharged  Pending Trial At The End Of The Year  \
# 0                             58                                  1085
# 1                              0                                    15
# 2                              1                                    40
# 3                             16                                  1166
# 4                              8                                   220
#
#    Total Amt. Of Fine Imposed During The Year (In Rupees)
# 0                                             818000
# 1                                                  0
# 2                                            1635000
# 3                                              84000
# 4                                              44000
#
# [5 rows x 26 columns]

# %%
Pending = df['Pending Investigation From Previous Year']
Total = df['Total Cases For Investigation']
States = df['STATE/UT']

# %%
plt.scatter(Pending , Total)

# %%
plt.hist(Pending)
# Out:
# (array([21.,  8.,  1.,  1.,  1.,  1.,  1.,  0.,  0.,  1.]),
#  array([   0. ,  136.4,  272.8,  409.2,  545.6,  682. ,  818.4,  954.8,
#         1091.2, 1227.6, 1364. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(Pending)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Pending Investigation From Previous Year', ylabel='Density'>

# %%
plt.barh(States, Pending)
# Out:
# <BarContainer object of 35 artists>

# %%
plt.boxplot(Pending)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x22643196f40>,
#   <matplotlib.lines.Line2D at 0x226431a3310>],
#  'caps': [<matplotlib.lines.Line2D at 0x226431a36a0>,
#   <matplotlib.lines.Line2D at 0x226431a3a30>],
#  'boxes': [<matplotlib.lines.Line2D at 0x22643196bb0>],
#  'medians': [<matplotlib.lines.Line2D at 0x226431a3dc0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x226431b0190>],
#  'means': []}
